# %%
# ============================================================
#   CELL 1 — Mount Google Drive
# ============================================================
from google.colab import drive
drive.mount('/content/drive')


# ============================================================
#   CELL 2 — Install & Import Libraries
# ============================================================
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import warnings
warnings.filterwarnings("ignore")

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, f1_score, matthews_corrcoef,
    confusion_matrix, roc_auc_score, roc_curve,
    ConfusionMatrixDisplay
)

print("✅ Libraries loaded")


# ============================================================
#   CELL 3 — Configuration
# ============================================================

FEATURE_DIR  = "/content/drive/MyDrive/Colab Notebooks/AIP Prediction/data/features"
RESULTS_DIR  = "/content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree"
FIGURES_DIR  = "/content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/figures/decision_tree"
MODELS_DIR   = "/content/drive/MyDrive/Colab Notebooks/AIP Prediction/models/decision_tree"

os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(FIGURES_DIR, exist_ok=True)
os.makedirs(MODELS_DIR,  exist_ok=True)

# ── All 11 feature datasets ──────────────────────────────────
DATASETS = {
    "AAC"     : "AAC_features.csv",
    "DPC"     : "DPC_features.csv",
    "CTDC"    : "CTDC_features.csv",
    "CTDT"    : "CTDT_features.csv",
    "GAAC"    : "GAAC_features.csv",
    "PAAC"    : "PAAC_features.csv",
    "ProtBERT": "ProtBERT_features.csv",
    "ProtT5"  : "ProtT5_features.csv",
    "ESM2"    : "ESM2_features.csv",
    "BioBERT" : "BioBERT_features.csv",
    "ESMC"    : "ESMC_features.csv",
}

# ── Decision Tree hyperparameters ────────────────────────────
DT_PARAMS = {
    "criterion"    : "gini",       # "gini" or "entropy"
    "max_depth"    : None,         # None = fully grown; try 5,10,15 to control overfitting
    "min_samples_split" : 2,
    "min_samples_leaf"  : 1,
    "class_weight" : "balanced",   # handles 1:1.5 class imbalance
    "random_state" : 42,
}

TEST_SIZE    = 0.30   # 30% test, 70% train
RANDOM_STATE = 42

print(f"✅ Config loaded")
print(f"   Datasets     : {len(DATASETS)}")
print(f"   Train/Test   : {int((1-TEST_SIZE)*100)}% / {int(TEST_SIZE*100)}%")
print(f"   DT criterion : {DT_PARAMS['criterion']}")
print(f"   Class weight : {DT_PARAMS['class_weight']}")


# ============================================================
#   CELL 4 — Metric Helper Functions
# ============================================================

def compute_metrics(y_true, y_pred, y_prob):
    """
    Compute all 6 performance metrics.

    Metrics:
      Accuracy    = (TP + TN) / (TP + TN + FP + FN)
      Sensitivity = TP / (TP + FN)   [Recall for positive class]
      Specificity = TN / (TN + FP)   [Recall for negative class]
      F1 Score    = 2 × (Precision × Recall) / (Precision + Recall)
      MCC         = Matthews Correlation Coefficient
      AUC         = Area Under ROC Curve

    Note: ACC = Accuracy (same metric, listed for clarity)
    """
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    accuracy    = accuracy_score(y_true, y_pred)
    sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0.0   # Recall / TPR
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0   # TNR
    f1          = f1_score(y_true, y_pred, zero_division=0)
    mcc         = matthews_corrcoef(y_true, y_pred)
    auc         = roc_auc_score(y_true, y_prob)

    return {
        "Accuracy"   : round(accuracy,    4),
        "Sensitivity": round(sensitivity, 4),
        "Specificity": round(specificity, 4),
        "F1_Score"   : round(f1,          4),
        "MCC"        : round(mcc,         4),
        "AUC"        : round(auc,         4),
        # Raw counts for reference
        "TP": int(tp), "TN": int(tn),
        "FP": int(fp), "FN": int(fn),
    }


def load_dataset(csv_path):
    """
    Load a feature CSV, auto-detect feature columns and label.
    Expects: seq_id column, feature columns, label column (last).
    """
    df = pd.read_csv(csv_path)

    # Drop non-feature columns
    drop_cols = [c for c in ["seq_id", "sequence", "length"]
                 if c in df.columns]
    df = df.drop(columns=drop_cols)

    # Label must be last column
    X = df.iloc[:, :-1].values
    y = df.iloc[:, -1].values

    return X, y, df.columns[-1], df.shape


# ============================================================
#   CELL 5 — Main Training Loop
# ============================================================

all_results  = []       # metrics for all datasets
best_model   = None     # best DT model object
best_name    = ""
best_auc     = -1.0
all_probs    = {}       # store probabilities per dataset

print("=" * 65)
print("  Decision Tree — Training & Evaluation on 11 Datasets")
print("=" * 65)

for ds_name, csv_file in DATASETS.items():

    csv_path = os.path.join(FEATURE_DIR, csv_file)

    # ── Skip if file not found ───────────────────────────────
    if not os.path.exists(csv_path):
        print(f"\n⏭  [{ds_name}] File not found — skipping: {csv_file}")
        continue

    print(f"\n{'─'*60}")
    print(f"  Dataset : {ds_name}  ({csv_file})")

    # ── Load & split ─────────────────────────────────────────
    X, y, label_col, shape = load_dataset(csv_path)
    print(f"  Shape   : {shape}  |  Features: {X.shape[1]}  |  "
          f"Pos: {y.sum()}  Neg: {(y==0).sum()}")

    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size    = TEST_SIZE,
        random_state = RANDOM_STATE,
        stratify     = y        # preserve class ratio in both splits
    )

    print(f"  Train   : {len(X_train)} samples  |  "
          f"Test: {len(X_test)} samples")

    # ── Scale features ───────────────────────────────────────
    scaler  = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test  = scaler.transform(X_test)

    # ── Train Decision Tree ──────────────────────────────────
    clf = DecisionTreeClassifier(**DT_PARAMS)
    clf.fit(X_train, y_train)

    # ── Predict ──────────────────────────────────────────────
    y_pred = clf.predict(X_test)
    y_prob = clf.predict_proba(X_test)[:, 1]   # probability of positive class

    # ── Metrics ──────────────────────────────────────────────
    metrics = compute_metrics(y_test, y_pred, y_prob)
    metrics["Dataset"]  = ds_name
    metrics["Features"] = X.shape[1]
    metrics["Train_N"]  = len(X_train)
    metrics["Test_N"]   = len(X_test)
    all_results.append(metrics)

    print(f"\n  ── Results ──────────────────────────────────────")
    print(f"  Accuracy    : {metrics['Accuracy']:.4f}")
    print(f"  Sensitivity : {metrics['Sensitivity']:.4f}")
    print(f"  Specificity : {metrics['Specificity']:.4f}")
    print(f"  F1 Score    : {metrics['F1_Score']:.4f}")
    print(f"  MCC         : {metrics['MCC']:.4f}")
    print(f"  AUC         : {metrics['AUC']:.4f}")
    print(f"  TP={metrics['TP']}  TN={metrics['TN']}  "
          f"FP={metrics['FP']}  FN={metrics['FN']}")

    # ── Save probabilities ───────────────────────────────────
    df_probs = pd.DataFrame({
        "y_true"      : y_test,
        "y_pred"      : y_pred,
        "prob_positive": y_prob,
        "prob_negative": 1 - y_prob,
    })
    prob_path = os.path.join(RESULTS_DIR, f"{ds_name}_DT_probabilities.csv")
    df_probs.to_csv(prob_path, index=False)

    all_probs[ds_name] = {
        "y_test": y_test,
        "y_pred": y_pred,
        "y_prob": y_prob,
        "clf"   : clf,
        "scaler": scaler,
    }

    # ── Track best model ─────────────────────────────────────
    if metrics["AUC"] > best_auc:
        best_auc   = metrics["AUC"]
        best_name  = ds_name
        best_model = clf
        best_scaler = scaler

    print(f"  Probabilities saved → {prob_path}")

print(f"\n{'='*65}")
print(f"  ✅ Training complete for {len(all_results)} datasets")
print(f"  🏆 Best model: {best_name}  (AUC = {best_auc:.4f})")
print(f"{'='*65}")


# ============================================================
#   CELL 6 — Results Summary Table
# ============================================================

metric_cols = ["Dataset", "Accuracy", "Sensitivity", "Specificity",
               "F1_Score", "MCC", "AUC", "Features"]

df_results = pd.DataFrame(all_results)[metric_cols].sort_values(
    "AUC", ascending=False
).reset_index(drop=True)

df_results.index += 1   # rank from 1

print("\n── Decision Tree Performance Summary (sorted by AUC) ──")
print(df_results.to_string())

# Save summary CSV
summary_path = os.path.join(RESULTS_DIR, "DT_all_results_summary.csv")
df_results.to_csv(summary_path, index=True, index_label="Rank")
print(f"\n✅ Summary saved → {summary_path}")


# ============================================================
#   CELL 7 — Save Best Model
# ============================================================

best_model_path  = os.path.join(MODELS_DIR, f"DT_best_model_{best_name}.joblib")
best_scaler_path = os.path.join(MODELS_DIR, f"DT_best_scaler_{best_name}.joblib")

joblib.dump(best_model,  best_model_path)
joblib.dump(best_scaler, best_scaler_path)

print(f"✅ Best model saved")
print(f"   Dataset : {best_name}")
print(f"   AUC     : {best_auc:.4f}")
print(f"   Model   : {best_model_path}")
print(f"   Scaler  : {best_scaler_path}")


# ============================================================
#   CELL 8 — Visualization 1: Metrics Heatmap (All Datasets)
# ============================================================

heat_cols = ["Accuracy", "Sensitivity", "Specificity", "F1_Score", "MCC", "AUC"]
heat_data = df_results.set_index("Dataset")[heat_cols]

fig, ax = plt.subplots(figsize=(13, max(5, len(heat_data) * 0.7)))

sns.heatmap(
    heat_data,
    annot     = True,
    fmt       = ".4f",
    cmap      = "YlGn",
    linewidths= 0.5,
    linecolor = "grey",
    vmin      = 0,
    vmax      = 1,
    ax        = ax,
    cbar_kws  = {"label": "Score"}
)

ax.set_title("Decision Tree — Performance Metrics Across All 11 Datasets",
             fontsize=14, fontweight="bold", pad=15)
ax.set_xlabel("Metric", fontsize=12)
ax.set_ylabel("Dataset", fontsize=12)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=10)
ax.set_xticklabels(ax.get_xticklabels(), rotation=15, ha="right", fontsize=10)

plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, "DT_metrics_heatmap.png"),
            dpi=150, bbox_inches="tight")
plt.show()
print("✅ Metrics heatmap saved")


# ============================================================
#   CELL 9 — Visualization 2: Grouped Bar Chart (All Metrics)
# ============================================================

fig, ax = plt.subplots(figsize=(16, 6))

x      = np.arange(len(df_results))
width  = 0.13
colors = ["#3498db", "#2ecc71", "#e67e22", "#9b59b6", "#e74c3c", "#1abc9c"]

for i, (col, color) in enumerate(zip(heat_cols, colors)):
    offset = (i - len(heat_cols) / 2 + 0.5) * width
    bars   = ax.bar(x + offset, df_results[col].values,
                    width, label=col, color=color,
                    alpha=0.85, edgecolor="white")

ax.set_xlabel("Dataset", fontsize=12)
ax.set_ylabel("Score", fontsize=12)
ax.set_title("Decision Tree — All Metrics per Dataset",
             fontsize=14, fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(df_results["Dataset"], rotation=20, ha="right", fontsize=10)
ax.set_ylim(0, 1.08)
ax.legend(fontsize=10, loc="lower right")
ax.grid(axis="y", alpha=0.3)
ax.axhline(0.5, color="grey", linestyle="--", linewidth=0.8, alpha=0.6)

plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, "DT_grouped_bar_chart.png"),
            dpi=150, bbox_inches="tight")
plt.show()
print("✅ Grouped bar chart saved")


# ============================================================
#   CELL 10 — Visualization 3: ROC Curves (All Datasets)
# ============================================================

fig, ax = plt.subplots(figsize=(10, 8))

cmap   = plt.cm.get_cmap("tab10", len(all_probs))
colors = [cmap(i) for i in range(len(all_probs))]

for (ds_name, data), color in zip(all_probs.items(), colors):
    fpr, tpr, _ = roc_curve(data["y_test"], data["y_prob"])
    auc_val     = roc_auc_score(data["y_test"], data["y_prob"])
    lw          = 2.5 if ds_name == best_name else 1.2
    ls          = "-"  if ds_name == best_name else "--"
    ax.plot(fpr, tpr, color=color, linewidth=lw, linestyle=ls,
            label=f"{ds_name} (AUC={auc_val:.4f})"
                  + (" ★" if ds_name == best_name else ""))

ax.plot([0, 1], [0, 1], "k--", linewidth=1, alpha=0.5, label="Random")
ax.set_xlabel("False Positive Rate", fontsize=12)
ax.set_ylabel("True Positive Rate", fontsize=12)
ax.set_title("Decision Tree — ROC Curves for All Datasets",
             fontsize=14, fontweight="bold")
ax.legend(fontsize=9, loc="lower right")
ax.grid(alpha=0.3)
ax.set_xlim([0, 1])
ax.set_ylim([0, 1.02])

plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, "DT_ROC_curves.png"),
            dpi=150, bbox_inches="tight")
plt.show()
print("✅ ROC curves saved")


# ============================================================
#   CELL 11 — Visualization 4: Confusion Matrix (Best Model)
# ============================================================

best_data = all_probs[best_name]
cm        = confusion_matrix(best_data["y_test"], best_data["y_pred"])

fig, ax = plt.subplots(figsize=(6, 5))
disp = ConfusionMatrixDisplay(
    confusion_matrix  = cm,
    display_labels    = ["Non-AIP (0)", "AIP (1)"]
)
disp.plot(cmap="Blues", ax=ax, colorbar=False)

ax.set_title(f"Confusion Matrix — Best Model: {best_name}\n"
             f"(AUC = {best_auc:.4f})",
             fontsize=12, fontweight="bold")

plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, f"DT_confusion_matrix_{best_name}.png"),
            dpi=150, bbox_inches="tight")
plt.show()
print(f"✅ Confusion matrix saved ({best_name})")


# ============================================================
#   CELL 12 — Visualization 5: AUC Ranking Bar Chart
# ============================================================

fig, ax = plt.subplots(figsize=(12, 5))

sorted_df = df_results.sort_values("AUC", ascending=True)
colors    = ["#e74c3c" if n != best_name else "#2ecc71"
             for n in sorted_df["Dataset"]]

bars = ax.barh(sorted_df["Dataset"], sorted_df["AUC"],
               color=colors, edgecolor="white", height=0.6)

# Add value labels
for bar, val in zip(bars, sorted_df["AUC"]):
    ax.text(bar.get_width() + 0.005, bar.get_y() + bar.get_height()/2,
            f"{val:.4f}", va="center", fontsize=10)

ax.axvline(0.5, color="grey", linestyle="--", linewidth=1, alpha=0.7,
           label="Random baseline (0.5)")
ax.set_xlabel("AUC Score", fontsize=12)
ax.set_title("Decision Tree — AUC Ranking Across All Datasets",
             fontsize=14, fontweight="bold")
ax.set_xlim(0, 1.08)
ax.legend(fontsize=10)
ax.grid(axis="x", alpha=0.3)

from matplotlib.patches import Patch
legend_elements = [Patch(facecolor="#2ecc71", label=f"Best: {best_name}"),
                   Patch(facecolor="#e74c3c", label="Others")]
ax.legend(handles=legend_elements, fontsize=10)

plt.tight_layout()
plt.savefig(os.path.join(FIGURES_DIR, "DT_AUC_ranking.png"),
            dpi=150, bbox_inches="tight")
plt.show()
print("✅ AUC ranking chart saved")


# ============================================================
#   CELL 13 — Final Summary
# ============================================================

best_row = df_results[df_results["Dataset"] == best_name].iloc[0]

print("=" * 65)
print("  DECISION TREE — FINAL SUMMARY")
print("=" * 65)
print(f"\n  Results saved to  : {RESULTS_DIR}")
print(f"  Figures saved to  : {FIGURES_DIR}")
print(f"  Model saved to    : {MODELS_DIR}")
print(f"\n{'─'*65}")
print(f"  {'Dataset':<12} {'Acc':>8} {'Sn':>8} {'Sp':>8} "
      f"{'F1':>8} {'MCC':>8} {'AUC':>8}")
print(f"{'─'*65}")
for _, row in df_results.iterrows():
    marker = " ★" if row["Dataset"] == best_name else ""
    print(f"  {row['Dataset']:<12} {row['Accuracy']:>8.4f} "
          f"{row['Sensitivity']:>8.4f} {row['Specificity']:>8.4f} "
          f"{row['F1_Score']:>8.4f} {row['MCC']:>8.4f} "
          f"{row['AUC']:>8.4f}{marker}")
print(f"{'─'*65}")
print(f"\n  🏆 Best Dataset : {best_name}")
print(f"     Accuracy     : {best_row['Accuracy']:.4f}")
print(f"     Sensitivity  : {best_row['Sensitivity']:.4f}")
print(f"     Specificity  : {best_row['Specificity']:.4f}")
print(f"     F1 Score     : {best_row['F1_Score']:.4f}")
print(f"     MCC          : {best_row['MCC']:.4f}")
print(f"     AUC          : {best_row['AUC']:.4f}")
print(f"\n  Metric Notes:")
print(f"     Sensitivity = Recall = TPR (True Positive Rate)")
print(f"     Specificity = TNR (True Negative Rate)")
print(f"     ACC         = Accuracy (same metric)")
print(f"     MCC range   : -1 (worst) to +1 (best)")
print("=" * 65)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Libraries loaded
# ✅ Config loaded
#    Datasets     : 11
#    Train/Test   : 70% / 30%
#    DT criterion : gini
#    Class weight : balanced
# =================================================================
#   Decision Tree — Training & Evaluation on 11 Datasets
# =================================================================
#
# ────────────────────────────────────────────────────────────
#   Dataset : AAC  (AAC_features.csv)
#   Shape   : (2190, 21)  |  Features: 20  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.6910
#   Sensitivity : 0.6122
#   Specificity : 0.7437
#   F1 Score    : 0.6133
#   MCC         : 0.3560
#   AUC         : 0.6779
#   TP=161  TN=293  FP=101  FN=102
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/AAC_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : DPC  (DPC_features.csv)
#   Shape   : (2190, 401)  |  Features: 400  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.6758
#   Sensitivity : 0.6692
#   Specificity : 0.6802
#   F1 Score    : 0.6230
#   MCC         : 0.3435
#   AUC         : 0.6747
#   TP=176  TN=268  FP=126  FN=87
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/DPC_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : CTDC  (CTDC_features.csv)
#   Shape   : (2190, 22)  |  Features: 21  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.6575
#   Sensitivity : 0.5932
#   Specificity : 0.7005
#   F1 Score    : 0.5810
#   MCC         : 0.2918
#   AUC         : 0.6468
#   TP=156  TN=276  FP=118  FN=107
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/CTDC_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : CTDT  (CTDT_features.csv)
#   Shape   : (2190, 22)  |  Features: 21  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.6575
#   Sensitivity : 0.5856
#   Specificity : 0.7056
#   F1 Score    : 0.5779
#   MCC         : 0.2899
#   AUC         : 0.6456
#   TP=154  TN=278  FP=116  FN=109
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/CTDT_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : GAAC  (GAAC_features.csv)
#   Shape   : (2190, 6)  |  Features: 5  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.6788
#   Sensitivity : 0.5817
#   Specificity : 0.7437
#   F1 Score    : 0.5919
#   MCC         : 0.3274
#   AUC         : 0.6597
#   TP=153  TN=293  FP=101  FN=110
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/GAAC_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : PAAC  (PAAC_features.csv)
#   Shape   : (2190, 24)  |  Features: 23  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.6728
#   Sensitivity : 0.6312
#   Specificity : 0.7005
#   F1 Score    : 0.6069
#   MCC         : 0.3280
#   AUC         : 0.6658
#   TP=166  TN=276  FP=118  FN=97
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/PAAC_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : ProtBERT  (ProtBERT_features.csv)
#   Shape   : (2190, 1025)  |  Features: 1024  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.5464
#   Sensitivity : 0.4943
#   Specificity : 0.5812
#   F1 Score    : 0.4659
#   MCC         : 0.0744
#   AUC         : 0.5378
#   TP=130  TN=229  FP=165  FN=133
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/ProtBERT_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : ProtT5  (ProtT5_features.csv)
#   Shape   : (2190, 1025)  |  Features: 1024  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.6043
#   Sensitivity : 0.4487
#   Specificity : 0.7081
#   F1 Score    : 0.4758
#   MCC         : 0.1606
#   AUC         : 0.5784
#   TP=118  TN=279  FP=115  FN=145
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/ProtT5_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : ESM2  (ESM2_features.csv)
#   Shape   : (2190, 1281)  |  Features: 1280  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.5571
#   Sensitivity : 0.4563
#   Specificity : 0.6244
#   F1 Score    : 0.4520
#   MCC         : 0.0804
#   AUC         : 0.5403
#   TP=120  TN=246  FP=148  FN=143
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/ESM2_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : BioBERT  (BioBERT_features.csv)
#   Shape   : (2190, 769)  |  Features: 768  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.5677
#   Sensitivity : 0.4601
#   Specificity : 0.6396
#   F1 Score    : 0.4601
#   MCC         : 0.0997
#   AUC         : 0.5498
#   TP=121  TN=252  FP=142  FN=142
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/BioBERT_DT_probabilities.csv
#
# ────────────────────────────────────────────────────────────
#   Dataset : ESMC  (ESMC_features.csv)
#   Shape   : (2190, 1153)  |  Features: 1152  |  Pos: 876  Neg: 1314
#   Train   : 1533 samples  |  Test: 657 samples
#
#   ── Results ──────────────────────────────────────
#   Accuracy    : 0.5753
#   Sensitivity : 0.4753
#   Specificity : 0.6421
#   F1 Score    : 0.4726
#   MCC         : 0.1172
#   AUC         : 0.5587
#   TP=125  TN=253  FP=141  FN=138
#   Probabilities saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/ESMC_DT_probabilities.csv
#
# =================================================================
#   ✅ Training complete for 11 datasets
#   🏆 Best model: AAC  (AUC = 0.6779)
# =================================================================
#
# ── Decision Tree Performance Summary (sorted by AUC) ──
#      Dataset  Accuracy  Sensitivity  Specificity  F1_Score     MCC     AUC  Features
# 1        AAC    0.6910       0.6122       0.7437    0.6133  0.3560  0.6779        20
# 2        DPC    0.6758       0.6692       0.6802    0.6230  0.3435  0.6747       400
# 3       PAAC    0.6728       0.6312       0.7005    0.6069  0.3280  0.6658        23
# 4       GAAC    0.6788       0.5817       0.7437    0.5919  0.3274  0.6597         5
# 5       CTDC    0.6575       0.5932       0.7005    0.5810  0.2918  0.6468        21
# 6       CTDT    0.6575       0.5856       0.7056    0.5779  0.2899  0.6456        21
# 7     ProtT5    0.6043       0.4487       0.7081    0.4758  0.1606  0.5784      1024
# 8       ESMC    0.5753       0.4753       0.6421    0.4726  0.1172  0.5587      1152
# 9    BioBERT    0.5677       0.4601       0.6396    0.4601  0.0997  0.5498       768
# 10      ESM2    0.5571       0.4563       0.6244    0.4520  0.0804  0.5403      1280
# 11  ProtBERT    0.5464       0.4943       0.5812    0.4659  0.0744  0.5378      1024
#
# ✅ Summary saved → /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree/DT_all_results_summary.csv
# ✅ Best model saved
#    Dataset : AAC
#    AUC     : 0.6779
#    Model   : /content/drive/MyDrive/Colab Notebooks/AIP Prediction/models/decision_tree/DT_best_model_AAC.joblib
#    Scaler  : /content/drive/MyDrive/Colab Notebooks/AIP Prediction/models/decision_tree/DT_best_scaler_AAC.joblib
# ✅ Metrics heatmap saved
# ✅ Grouped bar chart saved
# ✅ ROC curves saved
# ✅ Confusion matrix saved (AAC)
# ✅ AUC ranking chart saved
# =================================================================
#   DECISION TREE — FINAL SUMMARY
# =================================================================
#
#   Results saved to  : /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/decision_tree
#   Figures saved to  : /content/drive/MyDrive/Colab Notebooks/AIP Prediction/results/figures/decision_tree
#   Model saved to    : /content/drive/MyDrive/Colab Notebooks/AIP Prediction/models/decision_tree
#
# ─────────────────────────────────────────────────────────────────
#   Dataset           Acc       Sn       Sp       F1      MCC      AUC
# ─────────────────────────────────────────────────────────────────
#   AAC            0.6910   0.6122   0.7437   0.6133   0.3560   0.6779 ★
#   DPC            0.6758   0.6692   0.6802   0.6230   0.3435   0.6747
#   PAAC           0.6728   0.6312   0.7005   0.6069   0.3280   0.6658
#   GAAC           0.6788   0.5817   0.7437   0.5919   0.3274   0.6597
#   CTDC           0.6575   0.5932   0.7005   0.5810   0.2918   0.6468
#   CTDT           0.6575   0.5856   0.7056   0.5779   0.2899   0.6456
#   ProtT5         0.6043   0.4487   0.7081   0.4758   0.1606   0.5784
#   ESMC           0.5753   0.4753   0.6421   0.4726   0.1172   0.5587
#   BioBERT        0.5677   0.4601   0.6396   0.4601   0.0997   0.5498
#   ESM2           0.5571   0.4563   0.6244   0.4520   0.0804   0.5403
#   ProtBERT       0.5464   0.4943   0.5812   0.4659   0.0744   0.5378
# ─────────────────────────────────────────────────────────────────
#
#   🏆 Best Dataset : AAC
#      Accuracy     : 0.6910
#      Sensitivity  : 0.6122
#      Specificity  : 0.7437
#      F1 Score     : 0.6133
#      MCC          : 0.3560
#      AUC          : 0.6779
#
#   Metric Notes:
#      Sensitivity = Recall = TPR (True Positive Rate)
#      Specificity = TNR (True Negative Rate)
#      ACC         = Accuracy (same metric)
#      MCC range   : -1 (worst) to +1 (best)
# =================================================================
